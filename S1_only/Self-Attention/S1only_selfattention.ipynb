# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip -q install optuna tqdm ipywidgets pytorch-tabnet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.9 MB/s eta 0:00:00

# %%
# =========================
# Self-Attention S1 Baseline (with Early Stopping)
# =========================
import os, json, warnings, random, pickle
import numpy as np
import pandas as pd
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import average_precision_score, roc_auc_score, f1_score, accuracy_score, precision_recall_curve

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# ---------- Config ----------
TARGET_COLUMN     = 'binary_helpfulness'
TEST_SPLIT_RATIO  = 0.2
RANDOM_STATE      = 42
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"✅ Device = {DEVICE}")

FILE_PATHS = {
    "Amazon":  '/content/drive/MyDrive/1014/data/new_amazon.csv',
    "Coursera":'/content/drive/MyDrive/1014/data/new_coursera.csv',
    "Audible": '/content/drive/MyDrive/1014/data/new_audible.csv',
    "Hotel":   '/content/drive/MyDrive/1014/data/new_hotel.csv'
}
S1_FEATURES = {
    "Amazon":  ['Average_Rating','Rating','Deviation_Of_Star_Ratings','Time_Lapsed','Price','Text_Length','Valence','Arousal','Title_Length','Num_of_Ratings','Is_Photo','Flesch_Reading_Ease','FOG_Index','Sentiment_Score','new_depth','new_breadth'],
    "Coursera":['Average_Rating','Rating','Deviation_Of_Star_Ratings','Time_Lapsed','Num_of_Reviews','Num_of_Enrolled','Num_of_top_instructor_courses','Num_of_top_instructor_learners','Text_Length','Valence','Arousal','Num_of_Ratings','Flesch_Reading_Ease','FOG_Index','Sentiment_Score','new_depth','new_breadth'],
    "Audible": ['Average_Rating','Rating','Deviation_Of_Star_Ratings','Time_Lapsed','Text_Length','Valence','Arousal','Title_Length','Num_of_Ratings','Flesch_Reading_Ease','FOG_Index','Sentiment_Score','new_depth','new_breadth'],
    "Hotel":   ['Average_Rating','Rating','Deviation_Of_Star_Ratings','Time_Lapsed','Text_Length','Valence','Arousal','Title_Length','Num_of_Ratings','Flesch_Reading_Ease','FOG_Index','Sentiment_Score','new_depth','new_breadth','Is_Photo','Hotel_Grade','Employee_Friendliness_Score','Facility_Score','Cleanliness_Score','Comfort_Score','Value_For_Money_Score','Location_Score']
}

def set_seed(seed=RANDOM_STATE):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
set_seed()

def _make_numeric_df(df: pd.DataFrame) -> pd.DataFrame:
    num = df.apply(pd.to_numeric, errors='coerce')
    return num.fillna(num.median())

def find_best_threshold(y_true, prob):
    p, r, t = precision_recall_curve(y_true, prob)
    t = np.concatenate([t, [1.0]])
    f1 = (2*p*r)/np.clip(p+r, 1e-9, None)
    idx = int(np.nanargmax(f1))
    return float(t[idx]), float(f1[idx])

# ---------- Model ----------
class S1EmbeddingLayerWithFeatureEncoding(nn.Module):
    def __init__(self, n_features, embedding_dim, dropout=0.1):
        super().__init__()
        self.n_features, self.embedding_dim = n_features, embedding_dim
        self.feature_projections = nn.ModuleList([
            nn.Sequential(nn.Linear(1, embedding_dim), nn.LayerNorm(embedding_dim), nn.ReLU(), nn.Dropout(dropout))
            for _ in range(n_features)
        ])
        self.feature_type_embedding = nn.Embedding(n_features, embedding_dim)

    def forward(self, x):  # x: (B,F)
        B, F = x.shape
        embs = []
        for i in range(F):
            col = x[:, i:i+1]
            embs.append(self.feature_projections[i](col))
        H = torch.stack(embs, dim=1)                    # (B,F,D)
        type_idx = torch.arange(F, device=x.device)
        type_emb = self.feature_type_embedding(type_idx) # (F,D)
        return H + type_emb.unsqueeze(0)                # (B,F,D)

class S1_SelfAttention_Model(nn.Module):
    def __init__(self, n_s1_features, embedding_dim=128, n_layers=2, n_heads=4,
                 dim_ff=256, attn_dropout=0.1, resid_dropout=0.1,
                 use_mean=True, head_hidden=256):
        super().__init__()
        self.use_mean = use_mean
        self.s1_embedding = S1EmbeddingLayerWithFeatureEncoding(n_s1_features, embedding_dim, resid_dropout)
        self.cls_token = nn.Parameter(torch.zeros(1,1,embedding_dim))
        nn.init.trunc_normal_(self.cls_token, std=0.02)
        self.pos_embedding = nn.Parameter(torch.zeros(1, n_s1_features+1, embedding_dim))
        nn.init.trunc_normal_(self.pos_embedding, std=0.02)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=embedding_dim, nhead=n_heads, dim_feedforward=dim_ff,
            dropout=attn_dropout, batch_first=True, activation="gelu", norm_first=True
        )
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=n_layers, enable_nested_tensor=False)
        self.dropout = nn.Dropout(resid_dropout)

        head_in = embedding_dim*(2 if use_mean else 1)
        self.head = nn.Sequential(
            nn.LayerNorm(head_in),
            nn.Linear(head_in, head_hidden), nn.GELU(), nn.Dropout(resid_dropout),
            nn.Linear(head_hidden, 1)
        )

    def forward(self, x):  # x: (B,F)
        B = x.size(0)
        H = self.s1_embedding(x)             # (B,F,D)
        cls = self.cls_token.expand(B,-1,-1) # (B,1,D)
        H = torch.cat([cls, H], dim=1)       # (B,F+1,D)
        H = H + self.pos_embedding[:, :H.size(1), :]
        H = self.dropout(self.encoder(H))    # (B,F+1,D)
        cls_h = H[:,0]
        rep = torch.cat([cls_h, H[:,1:].mean(1)], dim=-1) if self.use_mean else cls_h
        return self.head(rep)                # (B,1)

    @torch.no_grad()
    def predict_proba(self, x):
        return torch.sigmoid(self.forward(x)).squeeze(-1)

# ---------- Train utils ----------
class NumpyDataset(Dataset):
    def __init__(self, X, y): self.X=X; self.y=y
    def __len__(self): return len(self.X)
    def __getitem__(self, i): return self.X[i], self.y[i]

def train_one_run(X_tr, y_tr, X_va, y_va, params):
    bs = params.get("batch_size", 1024)
    lr = params.get("lr", 2e-4)
    wd = params.get("weight_decay", 1e-4)
    epochs = params.get("max_epochs", 50)
    patience = params.get("patience", 7)

    model = S1_SelfAttention_Model(
        n_s1_features=X_tr.shape[1],
        embedding_dim=params.get("embedding_dim", 128),
        n_layers=params.get("n_layers", 2),
        n_heads=params.get("n_heads", 4),
        dim_ff=params.get("dim_ff", 256),
        attn_dropout=params.get("attn_dropout", 0.1),
        resid_dropout=params.get("resid_dropout", 0.1),
        use_mean=params.get("use_mean", True),
        head_hidden=params.get("head_hidden", 256)
    ).to(DEVICE)

    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=wd)
    crit = nn.BCEWithLogitsLoss()

    dl_tr = DataLoader(NumpyDataset(torch.tensor(X_tr,dtype=torch.float32),
                                    torch.tensor(y_tr,dtype=torch.float32)),
                       batch_size=bs, shuffle=True, drop_last=False)
    dl_va = DataLoader(NumpyDataset(torch.tensor(X_va,dtype=torch.float32),
                                    torch.tensor(y_va,dtype=torch.float32)),
                       batch_size=4096, shuffle=False, drop_last=False)

    best_pr, best_state, bad = -1.0, None, 0
    for ep in range(1, epochs+1):
        model.train()
        for xb, yb in dl_tr:
            xb, yb = xb.to(DEVICE), yb.to(DEVICE)
            logit = model(xb).squeeze(-1)
            loss = crit(logit, yb)
            opt.zero_grad(); loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()

        # validate PR-AUC
        model.eval(); probs=[]; ys=[]
        with torch.no_grad():
            for xb, yb in dl_va:
                xb=xb.to(DEVICE)
                probs.append(model.predict_proba(xb).cpu().numpy())
                ys.append(yb.numpy())
        pr = average_precision_score(np.concatenate(ys), np.concatenate(probs))
        if pr > best_pr + 1e-6:
            best_pr = pr; bad = 0
            best_state = {k:v.detach().cpu().clone() for k,v in model.state_dict().items()}
        else:
            bad += 1
            if bad >= patience: break

    if best_state is not None: model.load_state_dict(best_state)
    return model, best_pr

# ---------- Pipeline ----------
def run_baseline(platform, csv_path, features, save_root="/content/drive/MyDrive/1014/result_selfattn_baseline"):
    print(f"\n=== {platform} ===")
    df = pd.read_csv(csv_path)
    labels = df[TARGET_COLUMN].astype(int).values
    cols = [c for c in features if c in df.columns]
    X_all = _make_numeric_df(df[cols]).to_numpy()

    idx = np.arange(len(df))
    tr_idx, te_idx = train_test_split(idx, test_size=TEST_SPLIT_RATIO,
                                      random_state=RANDOM_STATE, stratify=labels)
    X_tr_raw, X_te_raw = X_all[tr_idx], X_all[te_idx]
    y_tr, y_te = labels[tr_idx], labels[te_idx]

    # scaler (fit only on train)
    scaler = StandardScaler().fit(X_tr_raw)
    X_tr = scaler.transform(X_tr_raw)
    X_te = scaler.transform(X_te_raw)

    # 내부 10%를 val로
    sub, val = train_test_split(np.arange(len(y_tr)), test_size=0.1,
                                random_state=RANDOM_STATE, stratify=y_tr)
    model, _ = train_one_run(X_tr[sub], y_tr[sub], X_tr[val], y_tr[val], {
        "embedding_dim": 128, "n_layers": 2, "n_heads": 4,
        "dim_ff": 256, "attn_dropout": 0.1, "resid_dropout": 0.1,
        "head_hidden": 256, "use_mean": True,
        "lr": 2e-4, "weight_decay": 1e-4,
        "batch_size": 1024, "max_epochs": 50, "patience": 7
    })

    # test
    with torch.no_grad():
        te_prob = model.predict_proba(torch.tensor(X_te, dtype=torch.float32).to(DEVICE)).cpu().numpy()
        tr_prob = model.predict_proba(torch.tensor(X_tr, dtype=torch.float32).to(DEVICE)).cpu().numpy()
    best_th, _ = find_best_threshold(y_tr, tr_prob)
    te_pred = (te_prob >= best_th).astype(int)

    metrics = {
        "Accuracy": float(accuracy_score(y_te, te_pred)),
        "PR_AUC":   float(average_precision_score(y_te, te_prob)),
        "ROC_AUC":  float(roc_auc_score(y_te, te_prob)),
        "F1_score": float(f1_score(y_te, te_pred)),
        "Best_Threshold": float(best_th)
    }
    print("Metrics:", metrics)

    # save
    save_dir = f"{save_root}/{platform}"
    os.makedirs(save_dir, exist_ok=True)
    pd.DataFrame({"index": te_idx, "s1_pred_proba": te_prob, "y_true": y_te,
                  "y_pred_at_best_th": te_pred}).to_csv(f"{save_dir}/s1_pred_proba.csv", index=False)
    with open(f"{save_dir}/results.json","w") as f: json.dump(metrics, f, indent=2)
    torch.save(model.state_dict(), f"{save_dir}/selfattn_model.pt")
    with open(f"{save_dir}/scaler.pkl","wb") as f: pickle.dump(scaler, f)
    print(f"Saved to {save_dir}")

# ---- run all
for platform, path in FILE_PATHS.items():
    run_baseline(platform, path, S1_FEATURES[platform])
# Out:
# ✅ Device = cuda
#
# === Amazon ===
# Metrics: {'Accuracy': 0.8874124318914711, 'PR_AUC': 0.4423823616605832, 'ROC_AUC': 0.8293833600002343, 'F1_score': 0.44837918823208933, 'Best_Threshold': 0.26705095171928406}
# Saved to /content/drive/MyDrive/1014/result_selfattn_baseline/Amazon
#
# === Coursera ===
# Metrics: {'Accuracy': 0.9505725348051735, 'PR_AUC': 0.45945118341144475, 'ROC_AUC': 0.9079666586586554, 'F1_score': 0.45305378304466726, 'Best_Threshold': 0.253726601600647}
# Saved to /content/drive/MyDrive/1014/result_selfattn_baseline/Coursera
#
# === Audible ===
# Metrics: {'Accuracy': 0.9097752446499624, 'PR_AUC': 0.34466288991550603, 'ROC_AUC': 0.8014308485629043, 'F1_score': 0.3775964391691395, 'Best_Threshold': 0.17664691805839539}
# Saved to /content/drive/MyDrive/1014/result_selfattn_baseline/Audible
#
# === Hotel ===
# Metrics: {'Accuracy': 0.8033070778168817, 'PR_AUC': 0.24491487655657249, 'ROC_AUC': 0.7114614503559873, 'F1_score': 0.28536634869088695, 'Best_Threshold': 0.134362131357193}
# Saved to /content/drive/MyDrive/1014/result_selfattn_baseline/Hotel

# %% [markdown]
# # Optuna 튜닝 + 5-fold CV(early stopping + fold별 Scaler)

# %%
# =========================
# Self-Attention + Optuna Tuning (5-fold CV, no leakage)
# =========================
import optuna
from sklearn.model_selection import StratifiedKFold

N_TRIALS = 30  # 필요하면 조절

def cv_objective_factory(X_train, y_train):
    def objective(trial):
        params = {
            "embedding_dim": trial.suggest_categorical("embedding_dim", [64, 96, 128, 160]),
            "n_layers": trial.suggest_int("n_layers", 1, 4),
            "n_heads": trial.suggest_categorical("n_heads", [2, 4, 8]),
            "dim_ff": trial.suggest_categorical("dim_ff", [128, 256, 384, 512]),
            "attn_dropout": trial.suggest_float("attn_dropout", 0.0, 0.3),
            "resid_dropout": trial.suggest_float("resid_dropout", 0.0, 0.3),
            "head_hidden": trial.suggest_categorical("head_hidden", [128, 256, 384]),
            "use_mean": trial.suggest_categorical("use_mean", [True, False]),
            "lr": trial.suggest_float("lr", 1e-4, 5e-3, log=True),
            "weight_decay": trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True),
            "batch_size": trial.suggest_categorical("batch_size", [512, 1024, 2048]),
            "max_epochs": 60,
            "patience": 8
        }
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
        pr_aucs = []
        for tr_idx, va_idx in skf.split(X_train, y_train):
            # ---- per fold scaler (no leakage)
            sc = StandardScaler().fit(X_train[tr_idx])
            X_tr = sc.transform(X_train[tr_idx])
            X_va = sc.transform(X_train[va_idx])
            y_tr, y_va = y_train[tr_idx], y_train[va_idx]

            model, val_pr = train_one_run(X_tr, y_tr, X_va, y_va, params)
            pr_aucs.append(val_pr)
            del model
            torch.cuda.empty_cache()
        return float(np.mean(pr_aucs))
    return objective

def run_tuned(platform, csv_path, features, save_root="/content/drive/MyDrive/1014/result_selfattn_tuned"):
    print(f"\n=== [Tuned] {platform} ===")
    df = pd.read_csv(csv_path)
    labels = df[TARGET_COLUMN].astype(int).values
    cols = [c for c in features if c in df.columns]
    X_all = _make_numeric_df(df[cols]).to_numpy()

    idx = np.arange(len(df))
    tr_idx, te_idx = train_test_split(idx, test_size=TEST_SPLIT_RATIO,
                                      random_state=RANDOM_STATE, stratify=labels)
    X_tr_raw, X_te_raw = X_all[tr_idx], X_all[te_idx]
    y_tr, y_te = labels[tr_idx], labels[te_idx]

    # ----- Optuna CV
    study = optuna.create_study(direction="maximize")
    study.optimize(cv_objective_factory(X_tr_raw, y_tr), n_trials=N_TRIALS)
    best_params = study.best_params
    print("Best Params:", best_params)

    # ----- Final train (train 90% / val 10% split for early stopping)
    sub, val = train_test_split(np.arange(len(y_tr)), test_size=0.1,
                                random_state=RANDOM_STATE, stratify=y_tr)
    sc_final = StandardScaler().fit(X_tr_raw[sub])
    X_sub = sc_final.transform(X_tr_raw[sub])
    X_val = sc_final.transform(X_tr_raw[val])
    X_te  = sc_final.transform(X_te_raw)
    y_sub, y_val = y_tr[sub], y_tr[val]

    model, _ = train_one_run(X_sub, y_sub, X_val, y_val, best_params)

    # ----- Evaluate
    with torch.no_grad():
        te_prob = model.predict_proba(torch.tensor(X_te, dtype=torch.float32).to(DEVICE)).cpu().numpy()
        tr_prob = model.predict_proba(torch.tensor(sc_final.transform(X_tr_raw), dtype=torch.float32).to(DEVICE)).cpu().numpy()
    best_th, _ = find_best_threshold(y_tr, tr_prob)
    te_pred = (te_prob >= best_th).astype(int)

    metrics = {
        "Accuracy": float(accuracy_score(y_te, te_pred)),
        "PR_AUC":   float(average_precision_score(y_te, te_prob)),
        "ROC_AUC":  float(roc_auc_score(y_te, te_prob)),
        "F1_score": float(f1_score(y_te, te_pred)),
        "Best_Threshold": float(best_th),
        "best_params": best_params
    }
    print("Metrics:", metrics)

    # save
    save_dir = f"{save_root}/{platform}"
    os.makedirs(save_dir, exist_ok=True)
    pd.DataFrame({"index": te_idx, "s1_pred_proba": te_prob, "y_true": y_te,
                  "y_pred_at_best_th": te_pred}).to_csv(f"{save_dir}/s1_pred_proba.csv", index=False)
    with open(f"{save_dir}/results.json","w") as f: json.dump(metrics, f, indent=2)
    torch.save(model.state_dict(), f"{save_dir}/selfattn_model.pt")
    with open(f"{save_dir}/scaler.pkl","wb") as f: pickle.dump(sc_final, f)
    print(f"Saved to {save_dir}")

# ---- run all (tuned)
for platform, path in FILE_PATHS.items():
    run_tuned(platform, path, S1_FEATURES[platform])
# Out:
# === [Tuned] Amazon ===
# [I 2025-10-13 09:30:58,646] A new study created in memory with name: no-name-82ab4fc1-cd77-47e4-8da9-0dc09bb283c4
# [I 2025-10-13 09:38:26,086] Trial 0 finished with value: 0.43799284265368427 and parameters: {'embedding_dim': 96, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 384, 'attn_dropout': 0.0999859604605935, 'resid_dropout': 0.09673533855880047, 'head_hidden': 384, 'use_mean': False, 'lr': 0.0002334761858808828, 'weight_decay': 4.284270583620203e-06, 'batch_size': 1024}. Best is trial 0 with value: 0.43799284265368427.
# [I 2025-10-13 09:45:13,235] Trial 1 finished with value: 0.4139311783045592 and parameters: {'embedding_dim': 64, 'n_layers': 2, 'n_heads': 8, 'dim_ff': 384, 'attn_dropout': 0.1224900618383829, 'resid_dropout': 0.19855560219190987, 'head_hidden': 128, 'use_mean': False, 'lr': 0.00044384895862144974, 'weight_decay': 0.0005197075608589421, 'batch_size': 1024}. Best is trial 0 with value: 0.43799284265368427.
# [I 2025-10-13 09:54:06,316] Trial 2 finished with value: 0.376520311122539 and parameters: {'embedding_dim': 160, 'n_layers': 4, 'n_heads': 8, 'dim_ff': 384, 'attn_dropout': 0.1502909821470352, 'resid_dropout': 0.05751777906187974, 'head_hidden': 384, 'use_mean': True, 'lr': 0.0021980144202211954, 'weight_decay': 3.8378859246591776e-05, 'batch_size': 512}. Best is trial 0 with value: 0.43799284265368427.
# [I 2025-10-13 10:02:16,148] Trial 3 finished with value: 0.4371832957409726 and parameters: {'embedding_dim': 128, 'n_layers': 4, 'n_heads': 2, 'dim_ff': 128, 'attn_dropout': 0.1720136695975438, 'resid_dropout': 0.15641636249236798, 'head_hidden': 384, 'use_mean': False, 'lr': 0.000505639288143845, 'weight_decay': 9.064648250590675e-06, 'batch_size': 1024}. Best is trial 0 with value: 0.43799284265368427.
# [I 2025-10-13 10:07:46,050] Trial 4 finished with value: 0.4189042063840242 and parameters: {'embedding_dim': 96, 'n_layers': 3, 'n_heads': 8, 'dim_ff': 128, 'attn_dropout': 0.11357694393843117, 'resid_dropout': 0.07702200576994024, 'head_hidden': 384, 'use_mean': True, 'lr': 0.0002548378519656408, 'weight_decay': 7.101534889509405e-05, 'batch_size': 2048}. Best is trial 0 with value: 0.43799284265368427.
# [I 2025-10-13 10:13:58,254] Trial 5 finished with value: 0.4200942834976068 and parameters: {'embedding_dim': 160, 'n_layers': 4, 'n_heads': 2, 'dim_ff': 384, 'attn_dropout': 0.14181150014438537, 'resid_dropout': 0.1656126977888795, 'head_hidden': 384, 'use_mean': False, 'lr': 0.00046486082466481456, 'weight_decay': 3.686245870570442e-05, 'batch_size': 2048}. Best is trial 0 with value: 0.43799284265368427.
# [I 2025-10-13 10:26:22,968] Trial 6 finished with value: 0.4585194805257077 and parameters: {'embedding_dim': 128, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 128, 'attn_dropout': 0.02855704090049832, 'resid_dropout': 0.04654814871703048, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00017094530593619195, 'weight_decay': 1.5595899044016186e-06, 'batch_size': 512}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 10:31:09,986] Trial 7 finished with value: 0.38031026312940075 and parameters: {'embedding_dim': 128, 'n_layers': 3, 'n_heads': 2, 'dim_ff': 256, 'attn_dropout': 0.28554531753933027, 'resid_dropout': 0.25102348475307384, 'head_hidden': 128, 'use_mean': False, 'lr': 0.0013638459852262032, 'weight_decay': 1.7501372816696274e-05, 'batch_size': 2048}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 10:35:42,673] Trial 8 finished with value: 0.4375758306093148 and parameters: {'embedding_dim': 160, 'n_layers': 1, 'n_heads': 8, 'dim_ff': 384, 'attn_dropout': 0.24839832798768494, 'resid_dropout': 0.004906996425052101, 'head_hidden': 256, 'use_mean': True, 'lr': 0.0006657902096148306, 'weight_decay': 2.2647850128600415e-05, 'batch_size': 2048}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 10:47:48,228] Trial 9 finished with value: 0.4544756531523495 and parameters: {'embedding_dim': 96, 'n_layers': 4, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.0234094319799808, 'resid_dropout': 0.2469040520718965, 'head_hidden': 256, 'use_mean': False, 'lr': 0.0007665440302940444, 'weight_decay': 7.469792114714248e-05, 'batch_size': 512}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 10:56:31,774] Trial 10 finished with value: 0.4531298083883362 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 128, 'attn_dropout': 0.003838551542675244, 'resid_dropout': 0.007402690736849127, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00010352330048740487, 'weight_decay': 1.1047278809975114e-06, 'batch_size': 512}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 11:03:27,395] Trial 11 finished with value: 0.3584352602102866 and parameters: {'embedding_dim': 96, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.0001121601577537823, 'resid_dropout': 0.29695881949028335, 'head_hidden': 256, 'use_mean': True, 'lr': 0.004004339776712399, 'weight_decay': 0.00029112103492936147, 'batch_size': 512}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 11:16:04,888] Trial 12 finished with value: 0.44075200278130316 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.0549594711317843, 'resid_dropout': 0.22541028360893617, 'head_hidden': 256, 'use_mean': True, 'lr': 0.00142237912669719, 'weight_decay': 1.965164011381157e-06, 'batch_size': 512}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 11:28:00,658] Trial 13 finished with value: 0.45699371809299627 and parameters: {'embedding_dim': 128, 'n_layers': 3, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.05407331238218129, 'resid_dropout': 0.11572762319854596, 'head_hidden': 256, 'use_mean': False, 'lr': 0.00010805000554025122, 'weight_decay': 0.00014641212125153795, 'batch_size': 512}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 11:40:02,261] Trial 14 finished with value: 0.4457298038610964 and parameters: {'embedding_dim': 128, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.06283028859786303, 'resid_dropout': 0.11348189524911848, 'head_hidden': 128, 'use_mean': False, 'lr': 0.00011066897256733596, 'weight_decay': 0.00016764575064677554, 'batch_size': 512}. Best is trial 6 with value: 0.4585194805257077.
# [I 2025-10-13 11:50:23,438] Trial 15 finished with value: 0.4632914474291308 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.060221876632914985, 'resid_dropout': 0.04577159662728221, 'head_hidden': 256, 'use_mean': True, 'lr': 0.00019165909280524868, 'weight_decay': 0.0006400421802097018, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 11:59:42,947] Trial 16 finished with value: 0.41563362226066697 and parameters: {'embedding_dim': 128, 'n_layers': 1, 'n_heads': 4, 'dim_ff': 128, 'attn_dropout': 0.1920677273830733, 'resid_dropout': 0.0443650136590134, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00021332371620922034, 'weight_decay': 0.000773743190272016, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 12:10:08,616] Trial 17 finished with value: 0.45688429042822243 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 8, 'dim_ff': 128, 'attn_dropout': 0.0871740388942471, 'resid_dropout': 0.04160518532902762, 'head_hidden': 256, 'use_mean': True, 'lr': 0.00017003997866281927, 'weight_decay': 6.38802990081257e-06, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 12:19:04,801] Trial 18 finished with value: 0.45749980848053334 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.03970474319905919, 'resid_dropout': 0.027111102227766633, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0003084458714792732, 'weight_decay': 2.8272675631543114e-06, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 12:25:12,057] Trial 19 finished with value: 0.3645914880587722 and parameters: {'embedding_dim': 64, 'n_layers': 1, 'n_heads': 2, 'dim_ff': 256, 'attn_dropout': 0.07834719983969782, 'resid_dropout': 0.07965154115322752, 'head_hidden': 256, 'use_mean': True, 'lr': 0.0001604995401003357, 'weight_decay': 1.0584082399236672e-05, 'batch_size': 1024}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 12:35:52,574] Trial 20 finished with value: 0.4523616733002388 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.21114575736998648, 'resid_dropout': 0.13496151220749306, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00033392545394420574, 'weight_decay': 1.1145926472870216e-06, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 12:45:02,615] Trial 21 finished with value: 0.46260695727955514 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.03418727374715128, 'resid_dropout': 0.03364819061846741, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0003074111068985501, 'weight_decay': 2.805751474299257e-06, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 12:53:34,999] Trial 22 finished with value: 0.45144660988806234 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.02791580163694874, 'resid_dropout': 0.06062577683870562, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00017835469004338504, 'weight_decay': 2.150837404393706e-06, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 13:02:56,182] Trial 23 finished with value: 0.45219975029436865 and parameters: {'embedding_dim': 128, 'n_layers': 1, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.026100489028076233, 'resid_dropout': 0.014437101609525535, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00014078773138432343, 'weight_decay': 4.696409561668036e-06, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 13:13:02,865] Trial 24 finished with value: 0.45732674639328935 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 128, 'attn_dropout': 0.07563789636933264, 'resid_dropout': 0.08305850394203476, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0003355998620810305, 'weight_decay': 3.1251331701293498e-06, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 13:23:05,732] Trial 25 finished with value: 0.46185733907908455 and parameters: {'embedding_dim': 128, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.0537221518981407, 'resid_dropout': 0.04026310249381377, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00025753327040585987, 'weight_decay': 1.4927524129506601e-06, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 13:34:09,199] Trial 26 finished with value: 0.46094130693940316 and parameters: {'embedding_dim': 128, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.09378912506079498, 'resid_dropout': 0.03208560958753727, 'head_hidden': 256, 'use_mean': True, 'lr': 0.0007687887748896963, 'weight_decay': 1.2227650338944535e-05, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 13:44:49,366] Trial 27 finished with value: 0.4546637954142551 and parameters: {'embedding_dim': 64, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.12521434581528967, 'resid_dropout': 0.0011322528754911312, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0002830177062553283, 'weight_decay': 0.0009977133092541484, 'batch_size': 512}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 13:50:45,306] Trial 28 finished with value: 0.45419464412079036 and parameters: {'embedding_dim': 160, 'n_layers': 3, 'n_heads': 2, 'dim_ff': 512, 'attn_dropout': 0.05704512227475078, 'resid_dropout': 0.06610236964446198, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0003890864021984267, 'weight_decay': 6.610841850165893e-05, 'batch_size': 2048}. Best is trial 15 with value: 0.4632914474291308.
# [I 2025-10-13 13:58:20,493] Trial 29 finished with value: 0.45053270128484 and parameters: {'embedding_dim': 96, 'n_layers': 3, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.10050283396617989, 'resid_dropout': 0.10161200478379157, 'head_hidden': 256, 'use_mean': True, 'lr': 0.0002335478827511577, 'weight_decay': 5.042287516963566e-06, 'batch_size': 1024}. Best is trial 15 with value: 0.4632914474291308.
# Best Params: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.060221876632914985, 'resid_dropout': 0.04577159662728221, 'head_hidden': 256, 'use_mean': True, 'lr': 0.00019165909280524868, 'weight_decay': 0.0006400421802097018, 'batch_size': 512}
# Metrics: {'Accuracy': 0.8896363838541087, 'PR_AUC': 0.4900413814890722, 'ROC_AUC': 0.8434756212145808, 'F1_score': 0.470242860955431, 'Best_Threshold': 0.2471323162317276, 'best_params': {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.060221876632914985, 'resid_dropout': 0.04577159662728221, 'head_hidden': 256, 'use_mean': True, 'lr': 0.00019165909280524868, 'weight_decay': 0.0006400421802097018, 'batch_size': 512}}
# Saved to /content/drive/MyDrive/1014/result_selfattn_tuned/Amazon
#
# === [Tuned] Coursera ===
# [I 2025-10-13 14:00:16,567] A new study created in memory with name: no-name-b91ddfd2-f404-4822-93ed-f567abc6c658
# [I 2025-10-13 14:06:24,028] Trial 0 finished with value: 0.40106296419399545 and parameters: {'embedding_dim': 96, 'n_layers': 1, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.26817908103657906, 'resid_dropout': 0.25124710013279544, 'head_hidden': 384, 'use_mean': False, 'lr': 0.004069212622457329, 'weight_decay': 2.6923589475885083e-05, 'batch_size': 2048}. Best is trial 0 with value: 0.40106296419399545.
# [I 2025-10-13 14:14:38,674] Trial 1 finished with value: 0.46157275242409346 and parameters: {'embedding_dim': 160, 'n_layers': 2, 'n_heads': 8, 'dim_ff': 384, 'attn_dropout': 0.2866816032054776, 'resid_dropout': 0.13539364433928333, 'head_hidden': 128, 'use_mean': False, 'lr': 0.0005758228474121655, 'weight_decay': 0.00026629964650972646, 'batch_size': 1024}. Best is trial 1 with value: 0.46157275242409346.
# [I 2025-10-13 14:25:10,261] Trial 2 finished with value: 0.4077044557117625 and parameters: {'embedding_dim': 128, 'n_layers': 1, 'n_heads': 8, 'dim_ff': 128, 'attn_dropout': 0.25804704639338194, 'resid_dropout': 0.15799970252745854, 'head_hidden': 128, 'use_mean': False, 'lr': 0.0009672427326065123, 'weight_decay': 1.4190525172850415e-06, 'batch_size': 512}. Best is trial 1 with value: 0.46157275242409346.
# [I 2025-10-13 14:32:40,832] Trial 3 finished with value: 0.4818227389284345 and parameters: {'embedding_dim': 64, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.14569975066297922, 'resid_dropout': 0.06490735593163599, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0005707346599717476, 'weight_decay': 0.0005672505774880444, 'batch_size': 2048}. Best is trial 3 with value: 0.4818227389284345.
# [I 2025-10-13 14:36:44,620] Trial 4 finished with value: 0.29581242737988345 and parameters: {'embedding_dim': 160, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 128, 'attn_dropout': 0.2854639588200141, 'resid_dropout': 0.09661206475538468, 'head_hidden': 256, 'use_mean': False, 'lr': 0.0029345502208195403, 'weight_decay': 4.8395584468947205e-06, 'batch_size': 512}. Best is trial 3 with value: 0.4818227389284345.
# [I 2025-10-13 14:44:05,504] Trial 5 finished with value: 0.3689420793202228 and parameters: {'embedding_dim': 96, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 128, 'attn_dropout': 0.259338899361452, 'resid_dropout': 0.21927525672765538, 'head_hidden': 256, 'use_mean': False, 'lr': 0.000158995837642959, 'weight_decay': 4.846962135285574e-06, 'batch_size': 2048}. Best is trial 3 with value: 0.4818227389284345.
# [I 2025-10-13 14:51:28,293] Trial 6 finished with value: 0.39924179794237297 and parameters: {'embedding_dim': 96, 'n_layers': 3, 'n_heads': 2, 'dim_ff': 128, 'attn_dropout': 0.24373829799591942, 'resid_dropout': 0.1668201285018926, 'head_hidden': 384, 'use_mean': True, 'lr': 0.0001887058852609341, 'weight_decay': 0.00028325468943809985, 'batch_size': 2048}. Best is trial 3 with value: 0.4818227389284345.
# [I 2025-10-13 15:04:04,441] Trial 7 finished with value: 0.47793434791364386 and parameters: {'embedding_dim': 160, 'n_layers': 1, 'n_heads': 2, 'dim_ff': 384, 'attn_dropout': 0.028554232982325244, 'resid_dropout': 0.05954003300755373, 'head_hidden': 384, 'use_mean': False, 'lr': 0.000159799857874553, 'weight_decay': 2.6749144367394877e-05, 'batch_size': 512}. Best is trial 3 with value: 0.4818227389284345.
# [I 2025-10-13 15:15:25,830] Trial 8 finished with value: 0.3923293091326824 and parameters: {'embedding_dim': 128, 'n_layers': 1, 'n_heads': 4, 'dim_ff': 128, 'attn_dropout': 0.2114994118877049, 'resid_dropout': 0.19006316886829672, 'head_hidden': 128, 'use_mean': False, 'lr': 0.0008569904116843927, 'weight_decay': 2.4686430949184855e-06, 'batch_size': 512}. Best is trial 3 with value: 0.4818227389284345.
# [I 2025-10-13 15:24:45,213] Trial 9 finished with value: 0.41263182409364496 and parameters: {'embedding_dim': 64, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.2267362584037538, 'resid_dropout': 0.1379959592489137, 'head_hidden': 256, 'use_mean': False, 'lr': 0.00026298724468230595, 'weight_decay': 7.430494075875411e-05, 'batch_size': 1024}. Best is trial 3 with value: 0.4818227389284345.
# [I 2025-10-13 15:32:09,221] Trial 10 finished with value: 0.5054256775814518 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.10882720372342189, 'resid_dropout': 0.008044683664999774, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0019212122896499373, 'weight_decay': 0.000862080671285502, 'batch_size': 2048}. Best is trial 10 with value: 0.5054256775814518.
# [I 2025-10-13 15:37:56,474] Trial 11 finished with value: 0.4834320680666958 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.10768282219712966, 'resid_dropout': 0.018071828744751498, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0018438410065532587, 'weight_decay': 0.000947525376946038, 'batch_size': 2048}. Best is trial 10 with value: 0.5054256775814518.
# [I 2025-10-13 15:45:29,210] Trial 12 finished with value: 0.5181763764659005 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.08841306829017283, 'resid_dropout': 0.004653916278830045, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0017372853341331407, 'weight_decay': 0.0009130050746683856, 'batch_size': 2048}. Best is trial 12 with value: 0.5181763764659005.
# [I 2025-10-13 15:53:23,657] Trial 13 finished with value: 0.5288964889883968 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.0640665012031447, 'resid_dropout': 0.0012123683849555298, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0019133905024305065, 'weight_decay': 9.462386314687875e-05, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 16:00:28,880] Trial 14 finished with value: 0.5146962758327398 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.01681963304241855, 'resid_dropout': 0.001995977899709098, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0016214597980746994, 'weight_decay': 7.182503611075692e-05, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 16:08:14,164] Trial 15 finished with value: 0.4638008652275777 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 2, 'dim_ff': 512, 'attn_dropout': 0.06355618578082133, 'resid_dropout': 0.2972703986664524, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0013132500545771626, 'weight_decay': 0.00011957321509872437, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 16:17:09,377] Trial 16 finished with value: 0.4458241403442774 and parameters: {'embedding_dim': 64, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.08723071952298776, 'resid_dropout': 0.05546204913003274, 'head_hidden': 128, 'use_mean': True, 'lr': 0.004367006855679937, 'weight_decay': 0.00027546789604136686, 'batch_size': 1024}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 16:24:49,327] Trial 17 finished with value: 0.4346948714641313 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.17007857203743187, 'resid_dropout': 0.10249970476785823, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00035059672373983803, 'weight_decay': 1.0442760500795101e-05, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 16:29:21,854] Trial 18 finished with value: 0.39900660185601433 and parameters: {'embedding_dim': 128, 'n_layers': 4, 'n_heads': 2, 'dim_ff': 256, 'attn_dropout': 0.05989363346963984, 'resid_dropout': 0.03154480360116913, 'head_hidden': 384, 'use_mean': True, 'lr': 0.0029336311621369748, 'weight_decay': 0.00013786789454702458, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 16:39:27,660] Trial 19 finished with value: 0.5124280424817135 and parameters: {'embedding_dim': 64, 'n_layers': 3, 'n_heads': 8, 'dim_ff': 384, 'attn_dropout': 0.14349091413380707, 'resid_dropout': 0.09905750637842849, 'head_hidden': 256, 'use_mean': True, 'lr': 0.0010758077438400321, 'weight_decay': 3.5401579260187474e-05, 'batch_size': 1024}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 16:46:54,874] Trial 20 finished with value: 0.50019629107616 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.04564756359980083, 'resid_dropout': 0.039936877396813494, 'head_hidden': 128, 'use_mean': True, 'lr': 0.002356536279221463, 'weight_decay': 0.0004326208199468274, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 16:54:00,813] Trial 21 finished with value: 0.5132077435536051 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.017703931307336742, 'resid_dropout': 0.0020666276071436, 'head_hidden': 128, 'use_mean': True, 'lr': 0.001458503801437834, 'weight_decay': 6.969725566094063e-05, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 17:01:21,478] Trial 22 finished with value: 0.5081989578261594 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.005588286082440684, 'resid_dropout': 0.004906139526853801, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0015145914243512748, 'weight_decay': 5.155189063055243e-05, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 17:08:00,920] Trial 23 finished with value: 0.49034592807432203 and parameters: {'embedding_dim': 64, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.08465527678160858, 'resid_dropout': 0.07171209487498859, 'head_hidden': 128, 'use_mean': True, 'lr': 0.003171819274399316, 'weight_decay': 1.4592034100121327e-05, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 17:15:54,030] Trial 24 finished with value: 0.5091444151758363 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.03557386538191701, 'resid_dropout': 0.033831391944052006, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0007170815172835056, 'weight_decay': 0.0001666536705830309, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 17:22:57,738] Trial 25 finished with value: 0.513866112217885 and parameters: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.0028877047790725474, 'resid_dropout': 0.02658598067123973, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0021955282692344875, 'weight_decay': 1.3629878191910157e-05, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 17:30:24,633] Trial 26 finished with value: 0.4259636542169858 and parameters: {'embedding_dim': 128, 'n_layers': 3, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.11698708558782436, 'resid_dropout': 0.08178466991085523, 'head_hidden': 128, 'use_mean': True, 'lr': 0.00010258903137483385, 'weight_decay': 8.99629082925144e-05, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 17:36:55,527] Trial 27 finished with value: 0.44040923997530734 and parameters: {'embedding_dim': 160, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.058959238866172, 'resid_dropout': 0.04906664367109554, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0013236670232192342, 'weight_decay': 4.449381897048685e-05, 'batch_size': 1024}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 17:48:48,363] Trial 28 finished with value: 0.45015304594361905 and parameters: {'embedding_dim': 96, 'n_layers': 3, 'n_heads': 8, 'dim_ff': 512, 'attn_dropout': 0.08264865007526785, 'resid_dropout': 0.1210623753309472, 'head_hidden': 256, 'use_mean': True, 'lr': 0.0022857027656430834, 'weight_decay': 0.00021188683192715796, 'batch_size': 512}. Best is trial 13 with value: 0.5288964889883968.
# [I 2025-10-13 17:54:17,505] Trial 29 finished with value: 0.41771654181984796 and parameters: {'embedding_dim': 96, 'n_layers': 4, 'n_heads': 2, 'dim_ff': 384, 'attn_dropout': 0.17260499860607037, 'resid_dropout': 0.254100439757255, 'head_hidden': 384, 'use_mean': True, 'lr': 0.0031865756233748236, 'weight_decay': 0.0005583394381161074, 'batch_size': 2048}. Best is trial 13 with value: 0.5288964889883968.
# Best Params: {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.0640665012031447, 'resid_dropout': 0.0012123683849555298, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0019133905024305065, 'weight_decay': 9.462386314687875e-05, 'batch_size': 2048}
# Metrics: {'Accuracy': 0.953414614053876, 'PR_AUC': 0.4782924317382559, 'ROC_AUC': 0.914723283187014, 'F1_score': 0.4682651622002821, 'Best_Threshold': 0.24127382040023804, 'best_params': {'embedding_dim': 64, 'n_layers': 4, 'n_heads': 4, 'dim_ff': 256, 'attn_dropout': 0.0640665012031447, 'resid_dropout': 0.0012123683849555298, 'head_hidden': 128, 'use_mean': True, 'lr': 0.0019133905024305065, 'weight_decay': 9.462386314687875e-05, 'batch_size': 2048}}
# Saved to /content/drive/MyDrive/1014/result_selfattn_tuned/Coursera
#
# === [Tuned] Audible ===
# [I 2025-10-13 17:55:11,301] A new study created in memory with name: no-name-5c1994c6-0555-4654-874a-3fce7a9c6489
# [I 2025-10-13 18:05:52,769] Trial 0 finished with value: 0.3392689350947518 and parameters: {'embedding_dim': 96, 'n_layers': 4, 'n_heads': 8, 'dim_ff': 256, 'attn_dropout': 0.026958728837422063, 'resid_dropout': 0.1708818346118249, 'head_hidden': 256, 'use_mean': True, 'lr': 0.0012921111962755226, 'weight_decay': 2.00608120294013e-05, 'batch_size': 512}. Best is trial 0 with value: 0.3392689350947518.
# [I 2025-10-13 18:13:15,198] Trial 1 finished with value: 0.32114060068213035 and parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 2, 'dim_ff': 384, 'attn_dropout': 0.10205303146115947, 'resid_dropout': 0.053774434017270785, 'head_hidden': 384, 'use_mean': False, 'lr': 0.0007134134848229149, 'weight_decay': 2.651805877226465e-05, 'batch_size': 512}. Best is trial 0 with value: 0.3392689350947518.
# [W 2025-10-13 18:15:13,614] Trial 2 failed with parameters: {'embedding_dim': 128, 'n_layers': 2, 'n_heads': 4, 'dim_ff': 512, 'attn_dropout': 0.22867619884108673, 'resid_dropout': 0.053291685977624965, 'head_hidden': 256, 'use_mean': True, 'lr': 0.003970336838359048, 'weight_decay': 2.3401358005399538e-05, 'batch_size': 2048} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipython-input-3655414886.py", line 35, in objective
#     model, val_pr = train_one_run(X_tr, y_tr, X_va, y_va, params)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-976559015.py", line 159, in train_one_run
#     nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py", line 36, in _no_grad_wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py", line 221, in clip_grad_norm_
#     total_norm = _get_total_norm(grads, norm_type, error_if_nonfinite, foreach)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py", line 36, in _no_grad_wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py", line 100, in _get_total_norm
#     torch.stack([norm.to(first_device) for norm in norms]), norm_type
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2025-10-13 18:15:13,615] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3655414886.py in <cell line: 0>()
#      99 # ---- run all (tuned)
#     100 for platform, path in FILE_PATHS.items():
# --> 101     run_tuned(platform, path, S1_FEATURES[platform])
#
# /tmp/ipython-input-3655414886.py in run_tuned(platform, csv_path, features, save_root)
#      55     # ----- Optuna CV
#      56     study = optuna.create_study(direction="maximize")
# ---> 57     study.optimize(cv_objective_factory(X_tr_raw, y_tr), n_trials=N_TRIALS)
#      58     best_params = study.best_params
#      59     print("Best Params:", best_params)
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     488                 If nested invocation of this method occurs.
#     489         """
# --> 490         _optimize(
#     491             study=self,
#     492             func=func,
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61     try:
#      62         if n_jobs == 1:
# ---> 63             _optimize_sequential(
#      64                 study,
#      65                 func,
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158
#     159         try:
# --> 160             frozen_trial_id = _run_trial(study, func, catch)
#     161         finally:
#     162             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     256         and not isinstance(func_err, catch)
#     257     ):
# --> 258         raise func_err
#     259     return trial._trial_id
#     260
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     199     with get_heartbeat_thread(trial._trial_id, study._storage):
#     200         try:
# --> 201             value_or_values = func(trial)
#     202         except exceptions.TrialPruned as e:
#     203             # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipython-input-3655414886.py in objective(trial)
#      33             y_tr, y_va = y_train[tr_idx], y_train[va_idx]
#      34
# ---> 35             model, val_pr = train_one_run(X_tr, y_tr, X_va, y_va, params)
#      36             pr_aucs.append(val_pr)
#      37             del model
#
# /tmp/ipython-input-976559015.py in train_one_run(X_tr, y_tr, X_va, y_va, params)
#     157             loss = crit(logit, yb)
#     158             opt.zero_grad(); loss.backward()
# --> 159             nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#     160             opt.step()
#     161
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py in _no_grad_wrapper(*args, **kwargs)
#      34     def _no_grad_wrapper(*args, **kwargs):
#      35         with torch.no_grad():
# ---> 36             return func(*args, **kwargs)
#      37
#      38     functools.update_wrapper(_no_grad_wrapper, func)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite, foreach)
#     219             )
#     220     grads = [p.grad for p in parameters if p.grad is not None]
# --> 221     total_norm = _get_total_norm(grads, norm_type, error_if_nonfinite, foreach)
#     222     _clip_grads_with_norm_(parameters, max_norm, total_norm, foreach)
#     223     return total_norm
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py in _no_grad_wrapper(*args, **kwargs)
#      34     def _no_grad_wrapper(*args, **kwargs):
#      35         with torch.no_grad():
# ---> 36             return func(*args, **kwargs)
#      37
#      38     functools.update_wrapper(_no_grad_wrapper, func)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/clip_grad.py in _get_total_norm(tensors, norm_type, error_if_nonfinite, foreach)
#      98
#      99     total_norm = torch.linalg.vector_norm(
# --> 100         torch.stack([norm.to(first_device) for norm in norms]), norm_type
#     101     )
#     102
#
# KeyboardInterrupt:
